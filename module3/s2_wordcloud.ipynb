# %% [markdown]
# # Building a wordcloud based on one year of bulletins

# %% [markdown]
# ## Créer un fichier contenant les bulletins d'une année donnée

# %%
year = 1958

# %%
from os import listdir
from os.path import isfile, join

data_path = '../data'
txt_path = '../data/txt'

txts = [f for f in listdir(txt_path) if isfile(join(txt_path, f)) and str(year) in f]

# %%
content_list = []
for txt in txts:
    with open(f'{txt_path}/{txt}', encoding='utf-8') as f:
        content_list.append(f.read())

with open(f'{data_path}/{year}.txt', 'w', encoding='utf-8') as f:
    f.write(' '.join(content_list))

# %% [markdown]
# ## Enlever les stopwords, les mots courts et non alphabétiques et stocker le résultat dans un nouveau fichier

# %%
from filtering import filtering

filtering(data_path, year)
# Out:
# ['/Users/Emma/Library/Python/3.8/lib/python/site-packages/ipykernel_launcher.py', '--ip=127.0.0.1', '--stdin=9053', '--control=9051', '--hb=9050', '--Session.signature_scheme="hmac-sha256"', '--Session.key=b"a23fdbbb-0b98-4515-a804-617118ccaf49"', '--shell=9052', '--transport="tcp"', '--iopub=9054', '--f=/var/folders/ky/cmhm_q4s0_76r604knj0_pn00000gn/T/tmp-129630HYU5UwKvVvh.json']

# %% [markdown]
# ## Créer le word cloud

# %%
import subprocess

command = [
    'wordcloud_cli',
    '--text', f'{data_path}/{year}_keywords.txt',
    '--imagefile', f'{data_path}/{year}.png',
    '--width', '2000',
    '--height', '1000',
]

subprocess.run(command, capture_output=True)
# Out:
# CompletedProcess(args=['wordcloud_cli', '--text', '../data/1958_keywords.txt', '--imagefile', '../data/1958.png', '--width', '2000', '--height', '1000'], returncode=0, stdout=b'', stderr=b'')

# %% [markdown]
# ## Afficher le word cloud

# %%
from IPython.display import Image

Image(filename=f'{data_path}/{year}.png')
